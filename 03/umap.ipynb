# %% [markdown]
# # UMAP
#
# 題材: [最新の次元圧縮法"UMAP"について](https://qiita.com/cheerfularge/items/27a55ebde4a671880666)

# %%
# 必要パッケージのインポートと不思議なおまじない

import matplotlib.pyplot as plt
import numpy as np
np.random.seed(0)
import sklearn as sl
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## t-SNEとUMAPを比較する

# %% [markdown]
# ### MNISTデータを準備する

# %%
from sklearn.datasets import load_digits

digits = load_digits()

# %%
digits.data.shape
# Out:
# (1797, 64)

# %%
digits.target.shape
# Out:
# (1797,)

# %% [markdown]
# ### t-SNEの場合

# %%
from sklearn.manifold import TSNE

# %timeit TSNE(n_components=2).fit_transform(digits.data)
# Out:
# 18.5 s ± 3.09 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
X_tsne = TSNE(n_components=2).fit_transform(digits.data)
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=digits.target)
plt.colorbar()

# %%
from umap import UMAP

# %timeit UMAP(n_components=2).fit_transform(digits.data)
# Out:
# 4.73 s ± 1.12 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
X_umap = UMAP(n_components=2).fit_transform(digits.data)
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=digits.target)
plt.colorbar()
